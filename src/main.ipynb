# %%
import pandas as pd

# %%
#df_raw = pd.read_csv("data\\raw\\results.csv")

df_raw = pd.read_csv("data/raw/results.csv")

df_processed = df_raw[df_raw["tournament"] == "FIFA World Cup"].copy()

df_processed.to_csv("data/raw/partidos-mundial.csv", index=False)

df_processed.head()
# Out:
#             date  home_team      away_team  home_score  away_score  \
# 1490  1930-07-13    Belgium  United States         0.0         3.0
# 1491  1930-07-13     France         Mexico         4.0         1.0
# 1492  1930-07-14     Brazil     Yugoslavia         1.0         2.0
# 1493  1930-07-14       Peru        Romania         1.0         3.0
# 1494  1930-07-15  Argentina         France         1.0         0.0
#
#           tournament        city  country  neutral
# 1490  FIFA World Cup  Montevideo  Uruguay     True
# 1491  FIFA World Cup  Montevideo  Uruguay     True
# 1492  FIFA World Cup  Montevideo  Uruguay     True
# 1493  FIFA World Cup  Montevideo  Uruguay     True
# 1494  FIFA World Cup  Montevideo  Uruguay     True

# %%
df_processed.shape
df_processed.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1055 entries, 1490 to 49495
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1055 non-null   str
#  1   home_team   1055 non-null   str
#  2   away_team   1055 non-null   str
#  3   home_score  1043 non-null   float64
#  4   away_score  1043 non-null   float64
#  5   tournament  1055 non-null   str
#  6   city        1055 non-null   str
#  7   country     1055 non-null   str
#  8   neutral     1055 non-null   bool
# dtypes: bool(1), float64(2), str(6)
# memory usage: 75.2 KB
